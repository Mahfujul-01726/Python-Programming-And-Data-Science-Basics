# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = {'Model1': [86,23,32,13,45,12],'Model2': [96,98,34,12,22,19], 'Model3': [56,23,44,12,32,33]}
df = pd.DataFrame (data, columns = ['Model1','Model2','Model3'], index=['I1', 'I2','I3','I4','I5','I6'])
df
# Out:
#     Model1  Model2  Model3
# I1      86      96      56
# I2      23      98      23
# I3      32      34      44
# I4      13      12      12
# I5      45      22      32
# I6      12      19      33

# %% [markdown]
# ## Line Plot

# %%
x = df['Model1']
plt.figure()
plt.plot(x, '-')

# %%
x = df['Model1']
plt.figure()
plt.plot(x, '-', color='red', label='Model 1 Plot', linewidth=2, linestyle='--')
plt.legend()
# Out:
# <ipython-input-6-da776ce3e39f>:3: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(x, '-', color='red', label='Model 1 Plot', linewidth=2, linestyle='--')

# %%
x = df['Model1']
y = df['Model2']
plt.figure()
plt.plot(x, color='red', label='Model 1', linewidth=2, linestyle='--')
plt.plot(y, color='g', label='Model 2', linewidth=3, linestyle='dotted')

plt.legend()

# %%
df
# Out:
#     Model1  Model2  Model3
# I1      86      96      56
# I2      23      98      23
# I3      32      34      44
# I4      13      12      12
# I5      45      22      32
# I6      12      19      33

# %% [markdown]
# ## Plot against each-other

# %%
x = df['Model1']
y = df['Model2']
plt.figure()
plt.plot(x, y, color='red', label='Model 1', linewidth=2, linestyle='solid')


plt.legend()

# %%
x = df['Model1']
y = df['Model2']
plt.figure()
plt.plot(x, y, color='b', label='Model 1 vs Model 2', linewidth=2, linestyle='solid')
plt.title("Trying Line Plot")

for i_x, i_y in zip(x, y):
    plt.text(i_x, i_y, '({}, {})'.format(i_x, i_y))

plt.xlabel("Model1-axis")
plt.ylabel("Model2-axis")

plt.legend()

# %% [markdown]
# ## Axis Size

# %%
x = df['Model1']
y = df['Model2']
plt.figure()
plt.plot(x, y, color='red', label='Model 1', linewidth=2, linestyle='solid')

plt.xlim(-10, 100)
plt.ylim(10, 100)


plt.legend()

# %%
x = df['Model1']
y = df['Model2']
plt.figure()

plt.plot(x, y, color='blue', label='Model 2', linewidth=2, linestyle='solid')
plt.axis('tight')


plt.legend()

# %%
x = df['Model1']
y = df['Model2']
plt.figure()

plt.plot(x, y, color='blue', label='Model 2', linewidth=2, linestyle='solid')
plt.axis('equal')


plt.legend()

# %% [markdown]
# ### OOP is slightly different

# %%
x = df['Model1']
y = df['Model2']

ax = plt.axes()
ax.plot(x, y)
ax.set(xlim=(0, 100), ylim=(-20, 120),
        xlabel='x', ylabel='sin(x)',
        title='A Simple Plot');
