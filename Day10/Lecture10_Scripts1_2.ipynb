# %%
import pandas as pd
df = pd.read_csv('sample_data.csv')
df.head()
# Out:
#         ID     Segment  Country     Product   Units Sold  \
# 0  entry-1  Government   Canada   Carretera       1618.5
# 1  entry-2  Government  Germany   Carretera       1321.0
# 2  entry-3   Midmarket   France   Carretera       2178.0
# 3  entry-4   Midmarket  Germany   Carretera        888.0
# 4  entry-5   Midmarket   Mexico   Carretera       2470.0
#
#     Manufacturing Price    Sale Price   Gross Sales        Profit         Date
# 0                    3.0          20.0   $32,370.00    $16,185.00   2014-01-01
# 1                    3.0          20.0   $26,420.00    $13,210.00   2014-01-01
# 2                    3.0          15.0   $32,670.00    $10,890.00   2014-06-01
# 3                    3.0          15.0   $13,320.00     $4,440.00   2014-06-01
# 4                    3.0          15.0   $37,050.00    $12,350.00   2014-06-01

# %%
df.isin(['Mexico']).any()
# Out:
# ID                       False
# Segment                  False
# Country                   True
#  Product                 False
# Units Sold               False
#  Manufacturing Price     False
#  Sale Price              False
#  Gross Sales             False
#  Profit                  False
# Date                     False
# dtype: bool

# %%
df[df.isin(['Mexico'])].stack().index.tolist()
# Out:
# [(4, 'Country'),
#  (10, 'Country'),
#  (12, 'Country'),
#  (17, 'Country'),
#  (21, 'Country'),
#  (23, 'Country'),
#  (24, 'Country'),
#  (31, 'Country'),
#  (59, 'Country'),
#  (65, 'Country'),
#  (66, 'Country'),
#  (68, 'Country'),
#  (78, 'Country'),
#  (84, 'Country'),
#  (93, 'Country'),
#  (94, 'Country'),
#  (105, 'Country'),
#  (106, 'Country'),
#  (111, 'Country'),
#  (114, 'Country'),
#  (122, 'Country'),
#  (127, 'Country'),
#  (129, 'Country'),
#  (130, 'Country'),
#  (131, 'Country'),
#  (136, 'Country'),
#  (138, 'Country'),
#  (167, 'Country'),
#  (170, 'Country'),
#  (173, 'Country'),
#  (176, 'Country'),
#  (177, 'Country'),
#  (187, 'Country'),
#  (198, 'Country'),
#  (200, 'Country'),
#  (207, 'Country'),
#  (208, 'Country'),
#  (209, 'Country'),
#  (216, 'Country'),
#  (219, 'Country'),
#  (220, 'Country'),
#  (221, 'Country'),
#  (228, 'Country'),
#  (233, 'Country'),
#  (235, 'Country'),
#  (239, 'Country'),
#  (253, 'Country'),
#  (275, 'Country'),
#  (280, 'Country'),
#  (291, 'Country'),
#  (295, 'Country'),
#  (297, 'Country'),
#  (300, 'Country'),
#  (310, 'Country'),
#  (312, 'Country'),
#  (314, 'Country'),
#  (315, 'Country'),
#  (340, 'Country'),
#  (343, 'Country'),
#  (351, 'Country'),
#  (361, 'Country'),
#  (363, 'Country'),
#  (370, 'Country'),
#  (374, 'Country'),
#  (379, 'Country'),
#  (381, 'Country'),
#  (382, 'Country'),
#  (387, 'Country'),
#  (397, 'Country'),
#  (400, 'Country'),
#  (401, 'Country'),
#  (404, 'Country'),
#  (413, 'Country'),
#  (414, 'Country'),
#  (418, 'Country'),
#  (422, 'Country'),
#  (426, 'Country'),
#  (435, 'Country'),
#  (439, 'Country'),
#  (443, 'Country'),
#  (445, 'Country'),
#  (448, 'Country'),
#  (451, 'Country'),
#  (452, 'Country'),
#  (464, 'Country'),
#  (477, 'Country'),
#  (478, 'Country'),
#  (480, 'Country'),
#  (489, 'Country'),
#  (500, 'Country'),
#  (508, 'Country'),
#  (511, 'Country'),
#  (513, 'Country'),
#  (518, 'Country'),
#  (523, 'Country'),
#  (524, 'Country'),
#  (527, 'Country'),
#  (530, 'Country'),
#  (532, 'Country'),
#  (533, 'Country'),
#  (534, 'Country'),
#  (536, 'Country'),
#  (538, 'Country'),
#  (542, 'Country'),
#  (544, 'Country'),
#  (547, 'Country'),
#  (548, 'Country'),
#  (549, 'Country'),
#  (550, 'Country'),
#  (553, 'Country'),
#  (554, 'Country'),
#  (555, 'Country'),
#  (556, 'Country'),
#  (557, 'Country'),
#  (559, 'Country'),
#  (565, 'Country'),
#  (571, 'Country'),
#  (583, 'Country'),
#  (584, 'Country'),
#  (592, 'Country'),
#  (601, 'Country'),
#  (603, 'Country'),
#  (604, 'Country'),
#  (610, 'Country'),
#  (612, 'Country'),
#  (625, 'Country'),
#  (631, 'Country'),
#  (636, 'Country'),
#  (638, 'Country'),
#  (647, 'Country'),
#  (652, 'Country'),
#  (664, 'Country'),
#  (665, 'Country'),
#  (669, 'Country'),
#  (672, 'Country'),
#  (673, 'Country'),
#  (679, 'Country'),
#  (682, 'Country'),
#  (696, 'Country'),
#  (697, 'Country')]

# %%
df.head()
# Out:
#         ID     Segment  Country     Product   Units Sold  \
# 0  entry-1  Government   Canada   Carretera       1618.5
# 1  entry-2  Government  Germany   Carretera       1321.0
# 2  entry-3   Midmarket   France   Carretera       2178.0
# 3  entry-4   Midmarket  Germany   Carretera        888.0
# 4  entry-5   Midmarket   Mexico   Carretera       2470.0
#
#     Manufacturing Price    Sale Price   Gross Sales        Profit         Date
# 0                    3.0          20.0   $32,370.00    $16,185.00   2014-01-01
# 1                    3.0          20.0   $26,420.00    $13,210.00   2014-01-01
# 2                    3.0          15.0   $32,670.00    $10,890.00   2014-06-01
# 3                    3.0          15.0   $13,320.00     $4,440.00   2014-06-01
# 4                    3.0          15.0   $37,050.00    $12,350.00   2014-06-01

# %%
df[df['Country'] == 'Mexico']
# Out:
#             ID           Segment Country     Product   Units Sold  \
# 4      entry-5         Midmarket  Mexico   Carretera       2470.0
# 10    entry-11         Midmarket  Mexico     Montana       2470.0
# 12    entry-13    Small Business  Mexico     Montana        958.0
# 17    entry-18         Midmarket  Mexico       Paseo        974.0
# 21    entry-22        Government  Mexico       Paseo        883.0
# ..         ...               ...     ...          ...         ...
# 673  entry-674        Government  Mexico       Paseo       2851.0
# 679  entry-680        Government  Mexico       Paseo       2151.0
# 682  entry-683  Channel Partners  Mexico        Velo        500.0
# 696  entry-697    Small Business  Mexico    Amarilla        546.0
# 697  entry-698        Government  Mexico     Montana       1368.0
#
#       Manufacturing Price    Sale Price     Gross Sales          Profit   \
# 4                      3.0          15.0     $37,050.00      $12,350.00
# 10                     5.0          15.0     $37,050.00      $12,350.00
# 12                     5.0         300.0   $2,87,400.00      $47,900.00
# 17                    10.0          15.0     $14,610.00       $4,870.00
# 21                    10.0           7.0      $6,181.00       $1,766.00
# ..                     ...           ...             ...             ...
# 673                   10.0         350.0   $9,97,850.00    $1,06,912.50
# 679                   10.0         350.0   $7,52,850.00      $80,662.50
# 682                  120.0          12.0      $6,000.00       $3,600.00
# 696                  260.0         300.0   $1,63,800.00       $2,730.00
# 697                    5.0           7.0      $9,576.00       $1,299.60
#
#            Date
# 4    2014-06-01
# 10   2014-06-01
# 12   2014-08-01
# 17   2014-02-01
# 21   2014-08-01
# ..          ...
# 673  2014-05-01
# 679  2013-11-01
# 682  2014-03-01
# 696  2014-10-01
# 697  2014-02-01
#
# [140 rows x 10 columns]

# %%
df[(df['Units Sold'] >= 2000) & (df['Units Sold'] <= 3000)]
# Out:
#             ID           Segment                   Country     Product   \
# 2      entry-3         Midmarket                    France   Carretera
# 4      entry-5         Midmarket                    Mexico   Carretera
# 7      entry-8  Channel Partners                    Canada     Montana
# 10    entry-11         Midmarket                    Mexico     Montana
# 11    entry-12        Enterprise                    Canada     Montana
# ..         ...               ...                       ...          ...
# 683  entry-684         Midmarket                    France        Velo
# 685  entry-686    Small Business  United States of America        Velo
# 686  entry-687        Enterprise  United States of America        Velo
# 692  entry-693        Enterprise                    Canada         VTT
# 695  entry-696    Small Business                    France    Amarilla
#
#      Units Sold   Manufacturing Price    Sale Price     Gross Sales   \
# 2        2178.0                    3.0          15.0     $32,670.00
# 4        2470.0                    3.0          15.0     $37,050.00
# 7        2518.0                    5.0          12.0     $30,216.00
# 10       2470.0                    5.0          15.0     $37,050.00
# 11       2665.5                    5.0         125.0   $3,33,187.50
# ..          ...                    ...           ...             ...
# 683      2826.0                  120.0          15.0     $42,390.00
# 685      2574.0                  120.0         300.0   $7,72,200.00
# 686      2438.0                  120.0         125.0   $3,04,750.00
# 692      2954.0                  250.0         125.0   $3,69,250.00
# 695      2475.0                  260.0         300.0   $7,42,500.00
#
#            Profit         Date
# 2      $10,890.00   2014-06-01
# 4      $12,350.00   2014-06-01
# 7      $22,662.00   2014-06-01
# 10     $12,350.00   2014-06-01
# 11     $13,327.50   2014-07-01
# ..             ...         ...
# 683     $7,771.50   2014-05-01
# 685    $12,870.00   2013-11-01
# 686   $(33,522.50)  2013-12-01
# 692   $(40,617.50)  2013-11-01
# 695    $12,375.00   2014-03-01
#
# [209 rows x 10 columns]

# %%
df[(df['Units Sold'] >= 2000) & (df['Units Sold'] <= 3000) & (df[' Manufacturing Price ']>=120)]
# Out:
#             ID           Segment                   Country    Product   \
# 33    entry-34  Channel Partners                   Germany       Velo
# 36    entry-37        Enterprise  United States of America       Velo
# 38    entry-39    Small Business                    Canada        VTT
# 39    entry-40  Channel Partners                   Germany        VTT
# 40    entry-41         Midmarket                    France        VTT
# ..         ...               ...                       ...         ...
# 683  entry-684         Midmarket                    France       Velo
# 685  entry-686    Small Business  United States of America       Velo
# 686  entry-687        Enterprise  United States of America       Velo
# 692  entry-693        Enterprise                    Canada        VTT
# 695  entry-696    Small Business                    France   Amarilla
#
#      Units Sold   Manufacturing Price    Sale Price     Gross Sales   \
# 33       2161.0                  120.0          12.0     $25,932.00
# 36       2821.0                  120.0         125.0   $3,52,625.00
# 38       2001.0                  250.0         300.0   $6,00,300.00
# 39       2838.0                  250.0          12.0     $34,056.00
# 40       2178.0                  250.0          15.0     $32,670.00
# ..          ...                    ...           ...             ...
# 683      2826.0                  120.0          15.0     $42,390.00
# 685      2574.0                  120.0         300.0   $7,72,200.00
# 686      2438.0                  120.0         125.0   $3,04,750.00
# 692      2954.0                  250.0         125.0   $3,69,250.00
# 695      2475.0                  260.0         300.0   $7,42,500.00
#
#             Profit         Date
# 33      $19,449.00   2014-03-01
# 36      $14,105.00   2014-08-01
# 38    $1,00,050.00   2014-02-01
# 39      $25,542.00   2014-04-01
# 40      $10,890.00   2014-06-01
# ..              ...         ...
# 683      $7,771.50   2014-05-01
# 685     $12,870.00   2013-11-01
# 686    $(33,522.50)  2013-12-01
# 692    $(40,617.50)  2013-11-01
# 695     $12,375.00   2014-03-01
#
# [86 rows x 10 columns]
