# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data2.csv')
df.head()
# Out:
#       Country        Type Product  Items  Price
# 0  Bangladesh  Government     Pen      3      5
# 1       Nepal     Private  Pencil      5     12
# 2  Bangladesh  Government  Pencil     10      5
# 3       China  Government     Pen      4      8
# 4  Bangladesh     Private     Pen     20      5

# %%
df_ind = df.set_index(['Country', 'Type', 'Product'])
df_ind
# Out:
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
# Nepal      Private    Pencil       5     12
# Bangladesh Government Pencil      10      5
# China      Government Pen          4      8
# Bangladesh Private    Pen         20      5
# China      Private    Pencil       4     12
# Kenya      Government Pen          5      5
#            Private    Pencil       4     10
#            Government Pencil       6     20
# Bangladesh Private    Pencil      10     12
#            Government Pen          6     10
#                       Pen          5      5

# %%
df_ind_sorted = df_ind.sort_index()
df_ind_sorted
# Out:
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#                       Pencil      10      5
#            Private    Pen         20      5
#                       Pencil      10     12
# China      Government Pen          4      8
#            Private    Pencil       4     12
# Kenya      Government Pen          5      5
#                       Pencil       6     20
#            Private    Pencil       4     10
# Nepal      Private    Pencil       5     12

# %%
df_ind_sorted.to_csv('Output.csv')

# %% [markdown]
# ## Access

# %%
df_ind_sorted.loc['Bangladesh','Government','Pen']
# Out:
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5

# %%
df_ind_sorted.loc['Bangladesh','Government']
# Out:
#          Items  Price
# Product
# Pen          3      5
# Pen          6     10
# Pen          5      5
# Pencil      10      5

# %%
df_ind_sorted.loc['Pen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pen'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_ind_sorted.loc['Bangladesh']
# Out:
#                     Items  Price
# Type       Product
# Government Pen          3      5
#            Pen          6     10
#            Pen          5      5
#            Pencil      10      5
# Private    Pen         20      5
#            Pencil      10     12

# %%
idx = pd.IndexSlice

df_ind_sorted.loc[idx['Bangladesh', ['Government', 'Private']], :]
# Out:
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#                       Pencil      10      5
#            Private    Pen         20      5
#                       Pencil      10     12

# %%
df_ind_sorted
# Out:
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#                       Pencil      10      5
#            Private    Pen         20      5
#                       Pencil      10     12
# China      Government Pen          4      8
#            Private    Pencil       4     12
# Kenya      Government Pen          5      5
#                       Pencil       6     20
#            Private    Pencil       4     10
# Nepal      Private    Pencil       5     12

# %% [markdown]
# ## Slicing

# %%
df_ind_sorted['Bangladesh':'China']
# Out:
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#                       Pencil      10      5
#            Private    Pen         20      5
#                       Pencil      10     12
# China      Government Pen          4      8
#            Private    Pencil       4     12

# %%
df_ind_sorted.loc[(slice(None), ['Government'], slice(None)), :]
# Out:
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#                       Pencil      10      5
# China      Government Pen          4      8
# Kenya      Government Pen          5      5
#                       Pencil       6     20

# %%
for idx, data in df_ind_sorted.groupby(level=0):
    print('---')
    print(idx)
    print(data)
# Out:
# ---
# Bangladesh
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#                       Pencil      10      5
#            Private    Pen         20      5
#                       Pencil      10     12
# ---
# China
#                             Items  Price
# Country Type       Product
# China   Government Pen          4      8
#         Private    Pencil       4     12
# ---
# Kenya
#                             Items  Price
# Country Type       Product
# Kenya   Government Pen          5      5
#                    Pencil       6     20
#         Private    Pencil       4     10
# ---
# Nepal
#                          Items  Price
# Country Type    Product
# Nepal   Private Pencil       5     12

# %%
for idx, data in df_ind_sorted.groupby(level=1):
    print('---')
    print(idx)
    print(data)
# Out:
# ---
# Government
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#                       Pencil      10      5
# China      Government Pen          4      8
# Kenya      Government Pen          5      5
#                       Pencil       6     20
# ---
# Private
#                             Items  Price
# Country    Type    Product
# Bangladesh Private Pen         20      5
#                    Pencil      10     12
# China      Private Pencil       4     12
# Kenya      Private Pencil       4     10
# Nepal      Private Pencil       5     12

# %%
for idx, data in df_ind_sorted.groupby(level=2):
    print('---')
    print(idx)
    print(data)
# Out:
# ---
# Pen
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pen          3      5
#                       Pen          6     10
#                       Pen          5      5
#            Private    Pen         20      5
# China      Government Pen          4      8
# Kenya      Government Pen          5      5
# ---
# Pencil
#                                Items  Price
# Country    Type       Product
# Bangladesh Government Pencil      10      5
#            Private    Pencil      10     12
# China      Private    Pencil       4     12
# Kenya      Government Pencil       6     20
#            Private    Pencil       4     10
# Nepal      Private    Pencil       5     12
