# %% [markdown]
# # **Quick Revision**

# %%
import pandas as pd

# %%
data = pd.read_csv('sample_data.csv')
data.head()
# Out:
#         ID     Segment  Country     Product   Units Sold  \
# 0  entry-1  Government   Canada   Carretera       1618.5
# 1  entry-2  Government  Germany   Carretera       1321.0
# 2  entry-3   Midmarket   France   Carretera       2178.0
# 3  entry-4   Midmarket  Germany   Carretera        888.0
# 4  entry-5   Midmarket   Mexico   Carretera       2470.0
#
#     Manufacturing Price    Sale Price   Gross Sales        Profit         Date
# 0                    3.0          20.0   $32,370.00    $16,185.00   2014-01-01
# 1                    3.0          20.0   $26,420.00    $13,210.00   2014-01-01
# 2                    3.0          15.0   $32,670.00    $10,890.00   2014-06-01
# 3                    3.0          15.0   $13,320.00     $4,440.00   2014-06-01
# 4                    3.0          15.0   $37,050.00    $12,350.00   2014-06-01

# %%
print(data['Country'])
# Out:
# 0                        Canada
# 1                       Germany
# 2                        France
# 3                       Germany
# 4                        Mexico
#                  ...
# 695                      France
# 696                      Mexico
# 697                      Mexico
# 698                      Canada
# 699    United States of America
# Name: Country, Length: 700, dtype: object

# %%
print(data[['ID', 'Country']])
# Out:
#             ID                   Country
# 0      entry-1                    Canada
# 1      entry-2                   Germany
# 2      entry-3                    France
# 3      entry-4                   Germany
# 4      entry-5                    Mexico
# ..         ...                       ...
# 695  entry-696                    France
# 696  entry-697                    Mexico
# 697  entry-698                    Mexico
# 698  entry-699                    Canada
# 699  entry-700  United States of America
#
# [700 rows x 2 columns]

# %%
data.set_index('ID', inplace=True)
data.head()
# Out:
#             Segment  Country     Product   Units Sold   Manufacturing Price   \
# ID
# entry-1  Government   Canada   Carretera       1618.5                    3.0
# entry-2  Government  Germany   Carretera       1321.0                    3.0
# entry-3   Midmarket   France   Carretera       2178.0                    3.0
# entry-4   Midmarket  Germany   Carretera        888.0                    3.0
# entry-5   Midmarket   Mexico   Carretera       2470.0                    3.0
#
#           Sale Price   Gross Sales        Profit         Date
# ID
# entry-1          20.0   $32,370.00    $16,185.00   2014-01-01
# entry-2          20.0   $26,420.00    $13,210.00   2014-01-01
# entry-3          15.0   $32,670.00    $10,890.00   2014-06-01
# entry-4          15.0   $13,320.00     $4,440.00   2014-06-01
# entry-5          15.0   $37,050.00    $12,350.00   2014-06-01

# %%
data.T
# Out:
# ID                          entry-1       entry-2       entry-3       entry-4  \
# Segment                  Government    Government     Midmarket     Midmarket
# Country                      Canada       Germany        France       Germany
#  Product                 Carretera     Carretera     Carretera     Carretera
# Units Sold                   1618.5        1321.0        2178.0         888.0
#  Manufacturing Price            3.0           3.0           3.0           3.0
#  Sale Price                    20.0          20.0          15.0          15.0
#  Gross Sales            $32,370.00    $26,420.00    $32,670.00    $13,320.00
#  Profit                 $16,185.00    $13,210.00    $10,890.00     $4,440.00
# Date                     2014-01-01    2014-01-01    2014-06-01    2014-06-01
#
# ID                          entry-5         entry-6       entry-7  \
# Segment                   Midmarket      Government     Midmarket
# ...

# %%
OneDArray = data['Country']
print(OneDArray)
# Out:
# ID
# entry-1                        Canada
# entry-2                       Germany
# entry-3                        France
# entry-4                       Germany
# entry-5                        Mexico
#                        ...
# entry-696                      France
# entry-697                      Mexico
# entry-698                      Mexico
# entry-699                      Canada
# entry-700    United States of America
# Name: Country, Length: 700, dtype: object

# %%
OneDArray = data.Country
print(OneDArray)
print(type(OneDArray))
# Out:
# ID
# entry-1                        Canada
# entry-2                       Germany
# entry-3                        France
# entry-4                       Germany
# entry-5                        Mexico
#                        ...
# entry-696                      France
# entry-697                      Mexico
# entry-698                      Mexico
# entry-699                      Canada
# entry-700    United States of America
# Name: Country, Length: 700, dtype: object
# <class 'pandas.core.series.Series'>

# %%
data["Cal_Total_Sales"] = data['Units Sold'] * data[' Sale Price ']
data.head()
# Out:
#             Segment  Country     Product   Units Sold   Manufacturing Price   \
# ID
# entry-1  Government   Canada   Carretera       1618.5                    3.0
# entry-2  Government  Germany   Carretera       1321.0                    3.0
# entry-3   Midmarket   France   Carretera       2178.0                    3.0
# entry-4   Midmarket  Germany   Carretera        888.0                    3.0
# entry-5   Midmarket   Mexico   Carretera       2470.0                    3.0
#
#           Sale Price   Gross Sales        Profit         Date  Cal_Total_Sales
# ID
# entry-1          20.0   $32,370.00    $16,185.00   2014-01-01          32370.0
# entry-2          20.0   $26,420.00    $13,210.00   2014-01-01          26420.0
# entry-3          15.0   $32,670.00    $10,890.00   2014-06-01          32670.0
# entry-4          15.0   $13,320.00     $4,440.00   2014-06-01          13320.0
# entry-5          15.0   $37,050.00    $12,350.00   2014-06-01          37050.0

# %%
data.values[0]
# Out:
# array(['Government', 'Canada', ' Carretera ', 1618.5, 3.0, 20.0,
#        ' $32,370.00 ', ' $16,185.00 ', '2014-01-01', 32370.0],
#       dtype=object)

# %% [markdown]
# # ***iLOC vs LOC***
#
#
# ---

# %%
data.iloc[:3, :2]
# Out:
#             Segment  Country
# ID
# entry-1  Government   Canada
# entry-2  Government  Germany
# entry-3   Midmarket   France

# %%
data.loc[:'entry-10', :'Units Sold']
# Out:
#                    Segment  Country     Product   Units Sold
# ID
# entry-1         Government   Canada   Carretera       1618.5
# entry-2         Government  Germany   Carretera       1321.0
# entry-3          Midmarket   France   Carretera       2178.0
# entry-4          Midmarket  Germany   Carretera        888.0
# entry-5          Midmarket   Mexico   Carretera       2470.0
# entry-6         Government  Germany   Carretera       1513.0
# entry-7          Midmarket  Germany     Montana        921.0
# entry-8   Channel Partners   Canada     Montana       2518.0
# entry-9         Government   France     Montana       1899.0
# entry-10  Channel Partners  Germany     Montana       1545.0

# %%
data.loc[data['Units Sold'] > 1000, ['Units Sold','Country', ' Product ']]
# Out:
#            Units Sold                   Country     Product
# ID
# entry-1        1618.5                    Canada   Carretera
# entry-2        1321.0                   Germany   Carretera
# entry-3        2178.0                    France   Carretera
# entry-5        2470.0                    Mexico   Carretera
# entry-6        1513.0                   Germany   Carretera
# ...               ...                       ...          ...
# entry-692      1175.0                   Germany         VTT
# entry-693      2954.0                    Canada         VTT
# entry-696      2475.0                    France    Amarilla
# entry-698      1368.0                    Mexico     Montana
# entry-700      1806.0  United States of America         VTT
#
# [499 rows x 3 columns]

# %%
data['entry-5':'entry-12']
# Out:
#                    Segment  Country     Product   Units Sold  \
# ID
# entry-5          Midmarket   Mexico   Carretera       2470.0
# entry-6         Government  Germany   Carretera       1513.0
# entry-7          Midmarket  Germany     Montana        921.0
# entry-8   Channel Partners   Canada     Montana       2518.0
# entry-9         Government   France     Montana       1899.0
# entry-10  Channel Partners  Germany     Montana       1545.0
# entry-11         Midmarket   Mexico     Montana       2470.0
# entry-12        Enterprise   Canada     Montana       2665.5
#
#            Manufacturing Price    Sale Price     Gross Sales          Profit   \
# ID
# entry-5                     3.0          15.0     $37,050.00      $12,350.00
# entry-6                     3.0         350.0   $5,29,550.00    $1,36,170.00
# entry-7                     5.0          15.0     $13,815.00       $4,605.00
# entry-8                     5.0          12.0     $30,216.00      $22,662.00
# ...

# %%
data[' Sale Price ']-data[' Manufacturing Price ']
# Out:
# ID
# entry-1       17.0
# entry-2       17.0
# entry-3       12.0
# entry-4       12.0
# entry-5       12.0
#              ...
# entry-696     40.0
# entry-697     40.0
# entry-698      2.0
# entry-699     -3.0
# entry-700   -238.0
# Length: 700, dtype: float64
