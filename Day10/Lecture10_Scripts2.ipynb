# %%
import pandas as pd

# %%
data = pd.read_csv('lecture10.csv')
data
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   NaN  44.0
# 2   3  16.0  55.0
# 3   4   NaN  66.0
# 4   5  20.0   NaN
# 5   6  22.0   NaN
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
df.fillna(0, inplace=True)
df
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   0.0  44.0
# 2   3  16.0  55.0
# 3   4   0.0  66.0
# 4   5  20.0   0.0
# 5   6  22.0   0.0
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
df['val1'].fillna(0, inplace=True)
df
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   0.0  44.0
# 2   3  16.0  55.0
# 3   4   0.0  66.0
# 4   5  20.0   NaN
# 5   6  22.0   NaN
# 6   7  24.0  99.0

# %%
df.isnull()
# Out:
#       ID   val1   val2
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False   True
# 5  False  False   True
# 6  False  False  False

# %%
df[df['val2'].isnull()]
# Out:
#    ID  val1  val2
# 4   5  20.0   NaN
# 5   6  22.0   NaN

# %%
df[df['val2'].notnull()]
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   0.0  44.0
# 2   3  16.0  55.0
# 3   4   0.0  66.0
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
df[df[['val1','val2']].notnull().all(axis=1)]
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 2   3  16.0  55.0
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
df.dropna()
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 2   3  16.0  55.0
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
print(df)
df.fillna(method='ffill',axis=0)
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   NaN  44.0
# 2   3  16.0  55.0
# 3   4   NaN  66.0
# 4   5  20.0   NaN
# 5   6  22.0   NaN
# 6   7  24.0  99.0
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2  12.0  44.0
# 2   3  16.0  55.0
# 3   4  16.0  66.0
# 4   5  20.0  66.0
# 5   6  22.0  66.0
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
print(df)
df.fillna(method='bfill',axis=0)
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   NaN  44.0
# 2   3  16.0  55.0
# 3   4   NaN  66.0
# 4   5  20.0   NaN
# 5   6  22.0   NaN
# 6   7  24.0  99.0
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2  16.0  44.0
# 2   3  16.0  55.0
# 3   4  20.0  66.0
# 4   5  20.0  99.0
# 5   6  22.0  99.0
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
print(df)
# Linear interpolation
df.interpolate(method='linear', inplace=True)
df
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   NaN  44.0
# 2   3  16.0  55.0
# 3   4   NaN  66.0
# 4   5  20.0   NaN
# 5   6  22.0   NaN
# 6   7  24.0  99.0
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2  14.0  44.0
# 2   3  16.0  55.0
# 3   4  18.0  66.0
# 4   5  20.0  77.0
# 5   6  22.0  88.0
# 6   7  24.0  99.0

# %%
df = pd.read_csv('lecture10.csv')
print(df)

df['val1'].fillna(df['val1'].mean(), inplace=True)
df
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2   NaN  44.0
# 2   3  16.0  55.0
# 3   4   NaN  66.0
# 4   5  20.0   NaN
# 5   6  22.0   NaN
# 6   7  24.0  99.0
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2  18.8  44.0
# 2   3  16.0  55.0
# 3   4  18.8  66.0
# 4   5  20.0   NaN
# 5   6  22.0   NaN
# 6   7  24.0  99.0

# %%
df['val2'].fillna(df['val2'].median(), inplace=True)
df
# Out:
#    ID  val1  val2
# 0   1  12.0  33.0
# 1   2  18.8  44.0
# 2   3  16.0  55.0
# 3   4  18.8  66.0
# 4   5  20.0  55.0
# 5   6  22.0  55.0
# 6   7  24.0  99.0
